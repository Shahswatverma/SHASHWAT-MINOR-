# %%
import os 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('google_stock_1000.csv')
df.head()
# Out:
#                   Date        Open        High         Low       Close  \
# 0  2021-01-01 00:00:00  142.161929  151.992817  138.916718  141.923872
# 1  2021-01-02 00:00:00  147.229931  156.236511  142.553513  155.148449
# 2  2021-01-03 00:00:00  186.492832  188.399192  179.428063  185.343226
# 3  2021-01-04 00:00:00  173.681450  176.464416  164.659885  169.012356
# 4  2021-01-05 00:00:00  193.428154  197.869685  187.083219  187.269913
#
#     Volume
# 0  1577461
# 1  2918538
# 2  2740927
# 3  4210826
# 4  3550946

# %%
df.shape
# Out:
# (1000, 6)

# %%
df.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
df.dtypes
# Out:
# Date       object
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume      int64
# dtype: object

# %%
df['Close'].plot()
# Out:
# <Axes: >

# %%
#plt.figure(figsize=(1000, 6))

#sns.heatmap(df.corr(), cmap="Blues", annot=True)
#plt.show()

# %%
x = df[['Open', 'High' , 'Low' , 'Volume']].values
y = df['Close'].values

# %% [raw]
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_test = train_test_split(x,y,test_size=0.2,random_state=0)
